# %%
# !pip install selenium
# !pip install webdriver-manager
# !pip install pandas
# !pip install beautifulsoup4

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from selenium import webdriver  
from webdriver_manager.chrome import ChromeDriverManager  
from selenium.webdriver.common.keys import Keys  
from selenium.webdriver.support.ui import Select 
from time import sleep
pd.set_option('display.max_columns', None)

# %% [markdown]
# Descripción:
# Acceso a la Página de La Casa del Libro: Utilizando Selenium, deberás automatizar el proceso de navegación hacia la página de libros de ficción en el sitio web de La Casa del Libro.
# Extracción de Datos de las 5 Primeras Páginas: Una vez en la página de libros de ficción, debes programar su script para que recorra las 5 primeras páginas de libros, extrayendo los siguientes datos de cada libro:
# Título del libro.
# Autor(es) del libro.
# Precio del libro.
# Editorial del libro.
# Idioma del libro.
# Número de páginas del libro.
# Almacenamiento de Datos: Los datos extraídos deben almacenarse en un DataFrame.

# %%
#acceso a la página web desde chrome
driver = webdriver.Chrome()
driver.get("https://www.casadellibro.com/")
#maximizamos la ventana para ver bien el resultado
driver.maximize_window()
sleep(5)
#aceptamos cookies
driver.find_element("css selector","#onetrust-accept-btn-handler").click()
sleep(8)
#vamos a la sección de libros de ficción
driver.find_element("css selector","#app > div.v-application--wrap > div.when-mobile > div.cabecera.desktop > div.bottom-row > div > div > div:nth-child(2) > a").click()
sleep(5)

# %%
diccionario_ficcion = {"titulo": [], "autor": [], "precio_original": [], "precio_descuento": [], "editorial": [], "idioma": [], "num_paginas": []}

for page_number in range(1, 6):
    sleep(5)    
    driver.find_element("css selector",f"#buscadorNF > div.col-md-9.col-12 > div > div:nth-child(4) > div > div > nav > ul > li:nth-child({page_number})").click()
   
    sleep(5)
    
    for i in range(1, 21):
        sleep(5)
        try:
            driver.find_element("css selector", f"#buscadorNF > div.col-md-9.col-12 > div > div.grid-view.mt-4 > div:nth-child({i}) > a").click()
            sleep(10)
        
            diccionario_ficcion["titulo"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.col-md-5.order-lg-2.col-12.order-1 > div > h1").text)
            diccionario_ficcion["autor"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.col-md-5.order-lg-2.col-12.order-1 > div > div.text-h5.d-flex.flex-wrap.author.mb-2.justify-center.justify-sm-start > div > a > span:nth-child(1)").text)
            diccionario_ficcion["precio_original"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.border-left.col-md-4.col-12.order-3 > div > div:nth-child(2) > span.discount").text)
            diccionario_ficcion["precio_descuento"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.border-left.col-md-4.col-12.order-3 > div > div:nth-child(3) > div.col.col-8").text)
            diccionario_ficcion["editorial"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(7) > div > div:nth-child(2) > div > div:nth-child(2) > div:nth-child(2) > span").text)
            diccionario_ficcion["idioma"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(7) > div > div:nth-child(2) > div > div:nth-child(3) > div:nth-child(2) > span").text)
            diccionario_ficcion["num_paginas"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(7) > div > div:nth-child(2) > div > div:nth-child(1) > div:nth-child(2) > span").text)
            sleep(5)
        except Exception as e:
            print(f"Error al procesar el elemento {i}:{str(e)}")
    driver.back()
driver.close()
# Out:
# Error al procesar el elemento 2:Message: no such element: Unable to locate element: {"method":"css selector","selector":"#buscadorNF > div.col-md-9.col-12 > div > div.grid-view.mt-4 > div:nth-child(2) > a"}
#   (Session info: chrome=118.0.5993.118); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF609368EF2+54786]
# 	(No symbol) [0x00007FF6092D5612]
# 	(No symbol) [0x00007FF60918A64B]
# 	(No symbol) [0x00007FF6091CB79C]
# 	(No symbol) [0x00007FF6091CB91C]
# 	(No symbol) [0x00007FF609206D87]
# 	(No symbol) [0x00007FF6091EBEAF]
# 	(No symbol) [0x00007FF609204D02]
# 	(No symbol) [0x00007FF6091EBC43]
# 	(No symbol) [0x00007FF6091C0941]
# 	(No symbol) [0x00007FF6091C1B84]
# 	GetHandleVerifier [0x00007FF6096B7F52+3524194]
# 	GetHandleVerifier [0x00007FF60970D800+3874576]
# 	GetHandleVerifier [0x00007FF609705D7F+3843215]
# ...

# %%
diccionario_ficcion
# Out:
# {'titulo': ['LA CHICA DEL VERANO (NOVELA)',
#   'LA CHICA DEL VERANO (NOVELA)',
#   'UN DETALLE MENOR',
#   '1984',
#   '1984'],
#  'autor': ['LA VECINA RUBIA',
#   'LA VECINA RUBIA',
#   'GEORGE ORWELL',
#   'GEORGE ORWELL'],
#  'precio_original': ['19,90 €', '19,90 €', '8,95 €', '8,95 €'],
#  'precio_descuento': ['18,90 €', '18,90 €', '8,50 €', '8,50 €'],
#  'editorial': ['TIMUN MAS', 'TIMUN MAS', 'DEBOLSILLO', 'DEBOLSILLO'],
#  'idioma': ['CASTELLANO', 'CASTELLANO', 'CASTELLANO', 'CASTELLANO'],
#  'num_paginas': ['424', '424', '352', '352']}

# %%
#he tenido que hacer un try except para poder iterar en el rango de páginas pero algunas páginas presentan problemas de iteración
for page_number in range(1, 6):
    sleep(5)    
    try:
        driver.find_element("css selector",f"#buscadorNF > div.col-md-9.col-12 > div > div:nth-child(4) > div > div > nav > ul > li:nth-child({page_number}) > button").click()
   
        sleep(5)
        
        diccionario_ficcion = {"titulo": [], "autor": [], "precio_original": [], "precio_descuento": [], "editorial": [], "idioma": [], "num_paginas": []}

    
        for i in range(1, 21):
            sleep(5)
            try:
                driver.find_element("css selector", f"#buscadorNF > div.col-md-9.col-12 > div > div.grid-view.mt-4 > div:nth-child({i}) > a").click()
                sleep(10)
        
                diccionario_ficcion["titulo"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.col-md-5.order-lg-2.col-12.order-1 > div > h1").text)
                diccionario_ficcion["autor"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.col-md-5.order-lg-2.col-12.order-1 > div > div.text-h5.d-flex.flex-wrap.author.mb-2.justify-center.justify-sm-start > div > a > span:nth-child(1)").text)
                diccionario_ficcion["precio_original"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.border-left.col-md-4.col-12.order-3 > div > div:nth-child(2) > span.discount").text)
                diccionario_ficcion["precio_descuento"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.border-left.col-md-4.col-12.order-3 > div > div:nth-child(3) > div.col.col-8").text)
                diccionario_ficcion["editorial"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(7) > div > div:nth-child(2) > div > div:nth-child(2) > div:nth-child(2) > span").text)
                diccionario_ficcion["idioma"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(7) > div > div:nth-child(2) > div > div:nth-child(3) > div:nth-child(2) > span").text)
                diccionario_ficcion["num_paginas"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(7) > div > div:nth-child(2) > div > div:nth-child(1) > div:nth-child(2) > span").text)
                sleep(5)
            except Exception as e:
                print(f"Error al procesar el elemento {i}:{str(e)}")
                
    except Exception as page_error:
        print(f"Error al procesar la página {page_number}: {str(page_error)}")       
    driver.back()
driver.close()
# Out:
# Error al procesar la página 1: Message: element click intercepted: Element <button data-v-05bce262="" disabled="disabled" type="button" aria-label="Previous page" class="v-pagination__navigation v-pagination__navigation--disabled">...</button> is not clickable at point (620, 535). Other element would receive the click: <li data-v-05bce262="">...</li>
#   (Session info: chrome=118.0.5993.118)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF609368EF2+54786]
# 	(No symbol) [0x00007FF6092D5612]
# 	(No symbol) [0x00007FF60918A64B]
# 	(No symbol) [0x00007FF6091D1A6B]
# 	(No symbol) [0x00007FF6091CFE39]
# 	(No symbol) [0x00007FF6091CDC08]
# 	(No symbol) [0x00007FF6091CCCC3]
# 	(No symbol) [0x00007FF6091C29CF]
# 	(No symbol) [0x00007FF6091EBE6A]
# 	(No symbol) [0x00007FF6091C22E6]
# 	(No symbol) [0x00007FF6091EC080]
# 	(No symbol) [0x00007FF609204D02]
# 	(No symbol) [0x00007FF6091EBC43]
# 	(No symbol) [0x00007FF6091C0941]
# 	(No symbol) [0x00007FF6091C1B84]
# ...

# %%
#iteración de los elementos en una misma página, 
# el try except se añaden pq hay algunos libros que tienen problemas para poder extraer la información que se pide en el diccionario.
#el except ayuda a saber cuáles son los elementos que presentan errores en la iteración.
diccionario_ficcion = {"titulo": [], "autor": [], "precio_original": [], "precio_descuento": [], "editorial": [], "idioma": [], "num_paginas": []}

for i in range(1, 21):
    sleep(5)
    
    try:
        driver.find_element("css selector", f"#buscadorNF > div.col-md-9.col-12 > div > div.grid-view.mt-4 > div:nth-child({i}) > a").click()
        sleep(10)
        
        diccionario_ficcion["titulo"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.col-md-5.order-lg-2.col-12.order-1 > div > h1").text)
        diccionario_ficcion["autor"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.col-md-5.order-lg-2.col-12.order-1 > div > div.text-h5.d-flex.flex-wrap.author.mb-2.justify-center.justify-sm-start > div > a > span:nth-child(1)").text)
        diccionario_ficcion["precio_original"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.border-left.col-md-4.col-12.order-3 > div > div:nth-child(2) > span.discount").text)
        diccionario_ficcion["precio_descuento"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.border-left.col-md-4.col-12.order-3 > div > div:nth-child(3) > div.col.col-8").text)
        diccionario_ficcion["editorial"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(7) > div > div:nth-child(2) > div > div:nth-child(2) > div:nth-child(2) > span").text)
        diccionario_ficcion["idioma"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(7) > div > div:nth-child(2) > div > div:nth-child(3) > div:nth-child(2) > span").text)
        diccionario_ficcion["num_paginas"].append(driver.find_element("css selector","#app > div.v-application--wrap > main > div > div > div > div:nth-child(7) > div > div:nth-child(2) > div > div:nth-child(1) > div:nth-child(2) > span").text)
        
        sleep(5)
    except Exception as e:
        print(f"Error al procesar el elemento {i}:{str(e)}")
    
    driver.back()

driver.close()
# Out:
# Error al procesar el elemento 4:Message: no such element: Unable to locate element: {"method":"css selector","selector":"#app > div.v-application--wrap > main > div > div > div > div:nth-child(7) > div > div:nth-child(2) > div > div:nth-child(2) > div:nth-child(2) > span"}
#   (Session info: chrome=118.0.5993.118); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF609368EF2+54786]
# 	(No symbol) [0x00007FF6092D5612]
# 	(No symbol) [0x00007FF60918A64B]
# 	(No symbol) [0x00007FF6091CB79C]
# 	(No symbol) [0x00007FF6091CB91C]
# 	(No symbol) [0x00007FF609206D87]
# 	(No symbol) [0x00007FF6091EBEAF]
# 	(No symbol) [0x00007FF609204D02]
# 	(No symbol) [0x00007FF6091EBC43]
# 	(No symbol) [0x00007FF6091C0941]
# 	(No symbol) [0x00007FF6091C1B84]
# 	GetHandleVerifier [0x00007FF6096B7F52+3524194]
# 	GetHandleVerifier [0x00007FF60970D800+3874576]
# ...

# %%
diccionario_ficcion
# Out:
# {'titulo': ['LA CHICA DEL VERANO (NOVELA)',
#   'LA ARMADURA DE LA LUZ (SAGA LOS PILARES DE LA TIERRA 5)',
#   'EL INFIERNO',
#   'EL PROBLEMA FINAL',
#   'TODO VUELVE (SERIE TODO ARDE 2)',
#   'LAS HIJAS DE LA CRIADA (PREMIO PLANETA 2023)',
#   'S. EL BARCO DE TESEO (edición en sin definir)',
#   'MALDITA ROMA (SERIE JULIO CESAR 2)',
#   'BOCABESADA',
#   'LOS INOCENTES',
#   'EL HOMBRE ILUMINADO (NOVELA SECRETA 4)',
#   'ROMPER EL HIELO',
#   'NO TE VERE MORIR.',
#   'MIRAFIORI',
#   'LOS DIARIOS DEL OPIO',
#   'HOLLY',
#   'LAS MADRES (LA NOVIA GITANA 4)',
#   'TRILOGÍA',
#   'EL CUCO DE CRISTAL'],
#  'autor': ['LA VECINA RUBIA',
#   'KEN FOLLETT',
#   'CARMEN MOLA',
#   'ARTURO PEREZ REVERTE',
#   'JUAN GOMEZ JURADO',
#   'SONSOLES ONEGA',
#   'J.J. ABRAMS',
#   'SANTIAGO POSTEGUILLO',
#   'JUAN DEL VAL',
#   'MARIA ORUÑA',
#   'BRANDON SANDERSON',
#   'HANNAH GRACE',
#   'ANTONIO MUÑOZ MOLINA',
#   'MANUEL JABOIS',
#   'DAVID JIMENEZ',
#   'STEPHEN KING',
#   'CARMEN MOLA',
# ...
